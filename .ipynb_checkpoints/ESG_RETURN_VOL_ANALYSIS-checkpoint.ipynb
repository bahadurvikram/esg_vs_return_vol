# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("data/esg_return_vol_clean_data.csv")
df.head()
# Out:
#    risk_rating_score risk_rating_assessment              industry_group  \
# 0               28.9            Medium Risk                   Retailing
# 1               27.7            Medium Risk  Telecommunication Services
# 2               22.5            Medium Risk             Pharmaceuticals
# 3               16.3               Low Risk         Software & Services
# 4               35.0              High Risk                       Banks
#
#   identifier                   country           company_name  ticker  return  \
# 0   NAS:FLWS  United States of America  1-800-flowers-com-inc    FLWS -0.2236
# 1    ETR:1U1                   Germany                 1-1-ag  1U1.DE -0.3420
# 2    NAS:TXG  United States of America       10x-genomics-inc     TXG -0.7357
# 3    WAR:11B                    Poland      11-bit-studios-sa  11B.WA -0.6866
# 4   NAS:SRCE  United States of America        1st-source-corp    SRCE  0.1023
#
#    volatility
# 0      0.4191
# 1      0.2791
# 2      0.6540
# 3      0.6431
# 4      0.3087

# %%
df.columns
# Out:
# Index(['risk_rating_score', 'risk_rating_assessment', 'industry_group',
#        'identifier', 'country', 'company_name', 'ticker', 'return',
#        'volatility'],
#       dtype='object')

# %%
def basic_analysis(df):
    """Perform initial statistical analysis"""
    # Summary statistics by ESG group
    summary = df.groupby('risk_rating_assessment').agg({
        'return': ['mean', 'median', 'std', 'count'],
        'volatility': ['mean', 'median']
    }).round(4)
    
    print("Performance by ESG Group:")
    print(summary)
    
    # Correlation analysis
    corr_matrix = df[['risk_rating_score', 'return', 'volatility']].corr()
    print("\nCorrelation Matrix:")
    print(corr_matrix)
    
    return summary, corr_matrix
def create_visualizations(df):
    """Generate all visualizations"""
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle('ESG Performance Analysis', fontsize=16)
    
    # Boxplot of returns by ESG group
    sns.boxplot(x='risk_rating_assessment', y='return', data=df, ax=axes[0, 0])
    axes[0, 0].set_title('Distribution of Returns by ESG Group')
    axes[0, 0].set_ylabel('Return')
    axes[0, 0].set_xlabel('ESG Rating Group')
    
    # Scatter plot of ESG score vs returns
    sns.regplot(x='risk_rating_score', y='return', data=df, ax=axes[0, 1], 
                scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
    axes[0, 1].set_title('ESG Score vs. Returns')
    axes[0, 1].set_ylabel('Return')
    axes[0, 1].set_xlabel('ESG Score')
    
    # Violin plot of volatility by ESG group
    sns.violinplot(x='risk_rating_assessment', y='volatility', data=df, ax=axes[1, 0])
    axes[1, 0].set_title('Volatility by ESG Group')
    axes[1, 0].set_ylabel('Volatility')
    axes[1, 0].set_xlabel('ESG Rating Group')
    
    # Bar plot of average returns
    df.groupby('risk_rating_assessment')['return'].mean().plot(kind='bar', ax=axes[1, 1])
    axes[1, 1].set_title('Average Returns by ESG Group')
    axes[1, 1].set_ylabel('Average Return')
    axes[1, 1].set_xlabel('ESG Rating Group')
    
    plt.tight_layout()
    plt.savefig('esg_performance_analysis.png', dpi=300)
    plt.show()

def perform_statistical_tests(df):
    """Conduct hypothesis testing"""
    groups = {}
    for esg_group in df['risk_rating_assessment'].unique():
        groups[esg_group] = df[df['risk_rating_assessment'] == esg_group]['return']
    
    # ANOVA test for multiple group comparison
    f_val, p_val = stats.f_oneway(*groups.values())
    print(f"\nANOVA Results: F-value={f_val:.4f}, p-value={p_val:.4f}")
    
    # Pairwise t-tests between groups
    from itertools import combinations
    print("\nPairwise t-tests (Bonferroni corrected):")
    for group1, group2 in combinations(groups.keys(), 2):
        t_val, p_val = stats.ttest_ind(groups[group1], groups[group2], equal_var=False)
        # Bonferroni correction for multiple comparisons
        corrected_p = p_val * 6  # 6 possible pairwise comparisons for 4 groups
        print(f"{group1} vs {group2}: t={t_val:.4f}, p={corrected_p:.4f} {'*' if corrected_p < 0.05 else ''}")

def industry_adjusted_analysis(df):
    """Control for industry effects"""
    if 'industry_group' in df.columns:
        # Calculate industry-adjusted returns
        df['industry_mean_return'] = df.groupby('industry_group')['return'].transform('mean')
        df['adjusted_return'] = df['return'] - df['industry_mean_return']
        
        # Plot adjusted returns
        plt.figure(figsize=(10, 6))
        sns.boxplot(x='risk_rating_assessment', y='adjusted_return', data=df)
        plt.title('Industry-Adjusted Returns by ESG Group')
        plt.ylabel('Industry-Adjusted Return')
        plt.xlabel('ESG Rating Group')
        plt.savefig('industry_adjusted_returns.png', dpi=300)
        plt.show()

# %%
# Basic analysis
summary_stats, corr_matrix = basic_analysis(df)
# Visualization
create_visualizations(df)
# Statistical testing
perform_statistical_tests(df)
# Industry-adjusted analysis if industry data available
industry_adjusted_analysis(df)
# Out:
# Performance by ESG Group:
#                         return                       volatility
#                           mean  median     std count       mean  median
# risk_rating_assessment
# High Risk               0.1063  0.0412  0.4962  2742     0.4444  0.3890
# Low Risk                0.1140  0.0352  1.7872  2828     0.4263  0.3194
# Medium Risk             0.1189  0.0472  0.6820  4646     0.5592  0.3624
# Negligible Risk         0.0517  0.0173  0.3098   206     0.2879  0.2608
# Severe Risk             0.0906  0.0321  0.4608  1007     0.4604  0.3934
#
# Correlation Matrix:
#                    risk_rating_score    return  volatility
# risk_rating_score           1.000000 -0.002704    0.004576
# return                     -0.002704  1.000000    0.269626
# volatility                  0.004576  0.269626    1.000000
# ANOVA Results: F-value=0.3586, p-value=0.8382
#
# Pairwise t-tests (Bonferroni corrected):
# Medium Risk vs Low Risk: t=0.1403, p=5.3308
# Medium Risk vs High Risk: t=0.9114, p=2.1725
# Medium Risk vs Severe Risk: t=1.6062, p=0.6503
# Medium Risk vs Negligible Risk: t=2.8243, p=0.0303 *
# Low Risk vs High Risk: t=0.2189, p=4.9606
# Low Risk vs Severe Risk: t=0.6393, p=3.1360
# Low Risk vs Negligible Risk: t=1.5591, p=0.7149
# High Risk vs Severe Risk: t=0.9090, p=2.1807
# High Risk vs Negligible Risk: t=2.3175, p=0.1270
# Severe Risk vs Negligible Risk: t=1.4942, p=0.8154

# %%
def find_extreme_outliers(df, column_name):
    try:
        # Calculate quartiles
        Q1 = df[column_name].quantile(0.25)
        Q3 = df[column_name].quantile(0.75)
        IQR = Q3 - Q1

        # Define bounds for extreme outliers (3 times the IQR)
        lower_bound = Q1 - 3 * IQR
        upper_bound = Q3 + 3 * IQR

        # Identify extreme outliers
        extreme_outliers = (df[column_name] < lower_bound) | (df[column_name] > upper_bound)
        return extreme_outliers

    except TypeError:
        print(f"Column '{column_name}' is not numeric and cannot be used to find outliers using the IQR method.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %%
df_outlier=df[find_extreme_outliers(df, 'return')]
df_outlier_gr=df_outlier.groupby('country')
print('Total data', len(df))
print('Total outlier data ', len(df_outlier))
df_outlier_gr.size()
df_use=df[~find_extreme_outliers(df, 'return')]
print('Data is use ',len(df_use))
# Out:
# Total data 11429
# Total outlier data  168
# Data is use  11261

# %%
def basic_analysis_return(df):
    """Perform initial statistical analysis"""
    # Summary statistics by ESG group
    summary = df.groupby('risk_rating_assessment').agg({
        'return': ['mean', 'median', 'std', 'count']
    }).round(4)
    
    print("Performance by ESG Group:")
    print(summary)

    # Correlation analysis
    corr_matrix = df[['risk_rating_score', 'return']].corr()
    print("\nCorrelation Matrix:")
    print(corr_matrix)
    
    return summary, corr_matrix
def create_visualizations_return(df):
    """Generate all visualizations"""
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle('ESG Performance Analysis', fontsize=16)
    
    # Boxplot of returns by ESG group
    sns.boxplot(x='risk_rating_assessment', y='return', data=df, ax=axes[0, 0])
    axes[0, 0].set_title('Distribution of Returns by ESG Group')
    axes[0, 0].set_ylabel('Return')
    axes[0, 0].set_xlabel('ESG Rating Group')
    
    # Scatter plot of ESG score vs returns
    sns.regplot(x='risk_rating_score', y='return', data=df, ax=axes[0, 1], 
                scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
    axes[0, 1].set_title('ESG Score vs. Returns')
    axes[0, 1].set_ylabel('Return')
    axes[0, 1].set_xlabel('ESG Score')
    
    # Violin plot of return by ESG group
    sns.violinplot(x='risk_rating_assessment', y='return', data=df, ax=axes[1, 0])
    axes[1, 0].set_title('Return by ESG Group')
    axes[1, 0].set_ylabel('Return')
    axes[1, 0].set_xlabel('ESG Rating Group')
    
    # Bar plot of average returns
    df.groupby('risk_rating_assessment')['return'].mean().plot(kind='bar', ax=axes[1, 1])
    axes[1, 1].set_title('Average Returns by ESG Group')
    axes[1, 1].set_ylabel('Average Return')
    axes[1, 1].set_xlabel('ESG Rating Group')
    
    plt.tight_layout()
    plt.savefig('esg_performance_analysis.png', dpi=300)
    plt.show()

def perform_statistical_tests_return(df):
    """Conduct hypothesis testing"""
    groups = {}
    for esg_group in df['risk_rating_assessment'].unique():
        groups[esg_group] = df[df['risk_rating_assessment'] == esg_group]['return']
    
    # ANOVA test for multiple group comparison
    f_val, p_val = stats.f_oneway(*groups.values())
    print(f"\nANOVA Results: F-value={f_val:.4f}, p-value={p_val:.4f}")
    
    # Pairwise t-tests between groups
    from itertools import combinations
    print("\nPairwise t-tests (Bonferroni corrected):")
    for group1, group2 in combinations(groups.keys(), 2):
        t_val, p_val = stats.ttest_ind(groups[group1], groups[group2], equal_var=False)
        # Bonferroni correction for multiple comparisons
        corrected_p = p_val * 6  # 6 possible pairwise comparisons for 4 groups
        print(f"{group1} vs {group2}: t={t_val:.4f}, p={corrected_p:.4f} {'*' if corrected_p < 0.05 else ''}")

def industry_adjusted_analysis_return(df):
    """Control for industry effects"""
    if 'industry_group' in df.columns:
        # Calculate industry-adjusted returns
        df['industry_mean_return'] = df.groupby('industry_group')['return'].transform('mean')
        df['adjusted_return'] = df['return'] - df['industry_mean_return']
        
        # Plot adjusted returns
        plt.figure(figsize=(10, 6))
        sns.boxplot(x='risk_rating_assessment', y='adjusted_return', data=df)
        plt.title('Industry-Adjusted Returns by ESG Group')
        plt.ylabel('Industry-Adjusted Return')
        plt.xlabel('ESG Rating Group')
        plt.savefig('industry_adjusted_returns.png', dpi=300)
        plt.show()

# %%
# Basic analysis
summary_stats, corr_matrix = basic_analysis_return(df_use)
# Visualization
create_visualizations_return(df_use)
# Statistical testing
perform_statistical_tests_return(df_use)
# Industry-adjusted analysis if industry data available
industry_adjusted_analysis_return(df_use)
# Out:
# Performance by ESG Group:
#                         return
#                           mean  median     std count
# risk_rating_assessment
# High Risk               0.0650  0.0348  0.3874  2691
# Low Risk                0.0584  0.0328  0.3385  2801
# Medium Risk             0.0699  0.0409  0.3667  4568
# Negligible Risk         0.0394  0.0150  0.2549   205
# Severe Risk             0.0625  0.0273  0.3554   996
#
# Correlation Matrix:
#                    risk_rating_score    return
# risk_rating_score           1.000000  0.003103
# return                      0.003103  1.000000
# ANOVA Results: F-value=0.7052, p-value=0.5883
#
# Pairwise t-tests (Bonferroni corrected):
# Medium Risk vs Low Risk: t=1.3681, p=1.0279
# Medium Risk vs High Risk: t=0.5266, p=3.5909
# Medium Risk vs Severe Risk: t=0.5899, p=3.3320
# Medium Risk vs Negligible Risk: t=1.6400, p=0.6137
# Low Risk vs High Risk: t=-0.6726, p=3.0073
# Low Risk vs Severe Risk: t=-0.3165, p=4.5099
# Low Risk vs Negligible Risk: t=1.0070, p=1.8893
# High Risk vs Severe Risk: t=0.1860, p=5.1147
# High Risk vs Negligible Risk: t=1.3293, p=1.1090
# Severe Risk vs Negligible Risk: t=1.0988, p=1.6351
# /var/folders/cm/69k42yy95z5gwss1vrkqcdgm0000gn/T/ipykernel_3987/96738009.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['industry_mean_return'] = df.groupby('industry_group')['return'].transform('mean')
# /var/folders/cm/69k42yy95z5gwss1vrkqcdgm0000gn/T/ipykernel_3987/96738009.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adjusted_return'] = df['return'] - df['industry_mean_return']

# %%
df_outlier_vol=df[find_extreme_outliers(df, 'volatility')]
df_outlier_vol_gr=df_outlier_vol.groupby('country')
print('Total data', len(df))
print('Total outlier volatility data ', len(df_outlier_vol))
print(df_outlier_vol_gr.size())
df_use_vol=df[~find_extreme_outliers(df, 'volatility')]
print('Data is use for volatility ',len(df_use_vol))
# Out:
# Total data 11429
# Total outlier volatility data  155
# country
# Australia                     4
# Brazil                        4
# Canada                        2
# China                        19
# France                        2
# Germany                       1
# Hong Kong                     5
# India                         2
# Indonesia                     1
# Malaysia                      1
# Mexico                        1
# Singapore                     1
# South Korea                   2
# Switzerland                   3
# Thailand                      1
# United Kingdom                3
# United States of America    103
# dtype: int64
# Data is use for volatility  11274

# %%
def basic_analysis_volatility(df):
    """Perform initial statistical analysis"""
    # Summary statistics by ESG group
    summary = df.groupby('risk_rating_assessment').agg({
        'volatility': ['mean', 'median', 'std', 'count']
    }).round(4)
    
    print("Performance by ESG Group:")
    print(summary)
    # Correlation analysis
    corr_matrix = df[['risk_rating_score', 'volatility']].corr()
    print("\nCorrelation Matrix:")
    print(corr_matrix)
    
    return summary, corr_matrix
def create_visualizations_volatility(df):
    """Generate all visualizations"""
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle('ESG Performance Analysis', fontsize=16)
    
    # Boxplot of volatility by ESG group
    sns.boxplot(x='risk_rating_assessment', y='volatility', data=df, ax=axes[0, 0])
    axes[0, 0].set_title('Distribution of Volatility by ESG Group')
    axes[0, 0].set_ylabel('Volatility')
    axes[0, 0].set_xlabel('ESG Rating Group')
    
    # Scatter plot of ESG score vs volatility
    sns.regplot(x='risk_rating_score', y='volatility', data=df, ax=axes[0, 1], 
                scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
    axes[0, 1].set_title('ESG Score vs. Volatility')
    axes[0, 1].set_ylabel('Volatility')
    axes[0, 1].set_xlabel('ESG Score')
    
    # Violin plot of volatility by ESG group
    sns.violinplot(x='risk_rating_assessment', y='volatility', data=df, ax=axes[1, 0])
    axes[1, 0].set_title('Volatility by ESG Group')
    axes[1, 0].set_ylabel('Volatility')
    axes[1, 0].set_xlabel('ESG Rating Group')
    
    # Bar plot of average volatility
    df.groupby('risk_rating_assessment')['volatility'].mean().plot(kind='bar', ax=axes[1, 1])
    axes[1, 1].set_title('Average Volatility by ESG Group')
    axes[1, 1].set_ylabel('Average Volatility')
    axes[1, 1].set_xlabel('ESG Rating Group')
    
    plt.tight_layout()
    plt.savefig('esg_performance_analysis.png', dpi=300)
    plt.show()

def perform_statistical_tests_volatility(df):
    """Conduct hypothesis testing"""
    groups = {}
    for esg_group in df['risk_rating_assessment'].unique():
        groups[esg_group] = df[df['risk_rating_assessment'] == esg_group]['volatility']
    
    # ANOVA test for multiple group comparison
    f_val, p_val = stats.f_oneway(*groups.values())
    print(f"\nANOVA Results: F-value={f_val:.4f}, p-value={p_val:.4f}")
    
    # Pairwise t-tests between groups
    from itertools import combinations
    print("\nPairwise t-tests (Bonferroni corrected):")
    for group1, group2 in combinations(groups.keys(), 2):
        t_val, p_val = stats.ttest_ind(groups[group1], groups[group2], equal_var=False)
        # Bonferroni correction for multiple comparisons
        corrected_p = p_val * 6  # 6 possible pairwise comparisons for 4 groups
        print(f"{group1} vs {group2}: t={t_val:.4f}, p={corrected_p:.4f} {'*' if corrected_p < 0.05 else ''}")

def industry_adjusted_analysis_volatility(df):
    """Control for industry effects"""
    if 'industry_group' in df.columns:
        # Calculate industry-adjusted returns
        df['industry_mean_volatility'] = df.groupby('industry_group')['volatility'].transform('mean')
        df['adjusted_volatility'] = df['volatility'] - df['industry_mean_volatility']
        
        # Plot adjusted returns
        plt.figure(figsize=(10, 6))
        sns.boxplot(x='risk_rating_assessment', y='adjusted_volatility', data=df)
        plt.title('Industry-Adjusted Volatility by ESG Group')
        plt.ylabel('Industry-Adjusted Volatility')
        plt.xlabel('ESG Rating Group')
        # plt.savefig('industry_adjusted_volatility.png', dpi=300)
        plt.show()

# %%
# Basic analysis
summary_stats, corr_matrix = basic_analysis_volatility(df_use_vol)
# Visualization
create_visualizations_volatility(df_use_vol)
# Statistical testing
perform_statistical_tests_volatility(df_use_vol)
# Industry-adjusted analysis if industry data available
industry_adjusted_analysis_volatility(df_use_vol)
# Out:
# Performance by ESG Group:
#                        volatility
#                              mean  median     std count
# risk_rating_assessment
# High Risk                  0.4214  0.3866  0.1757  2690
# Low Risk                   0.3489  0.3182  0.1513  2806
# Medium Risk                0.3921  0.3590  0.1695  4574
# Negligible Risk            0.2879  0.2608  0.1172   206
# Severe Risk                0.4253  0.3914  0.1566   998
#
# Correlation Matrix:
#                    risk_rating_score  volatility
# risk_rating_score           1.000000    0.174268
# volatility                  0.174268    1.000000
# ANOVA Results: F-value=99.6057, p-value=0.0000
#
# Pairwise t-tests (Bonferroni corrected):
# Medium Risk vs Low Risk: t=11.3744, p=0.0000 *
# Medium Risk vs High Risk: t=-6.9684, p=0.0000 *
# Medium Risk vs Severe Risk: t=-5.9798, p=0.0000 *
# Medium Risk vs Negligible Risk: t=12.1978, p=0.0000 *
# Low Risk vs High Risk: t=-16.3841, p=0.0000 *
# Low Risk vs Severe Risk: t=-13.3606, p=0.0000 *
# Low Risk vs Negligible Risk: t=7.0467, p=0.0000 *
# High Risk vs Severe Risk: t=-0.6425, p=3.1236
# High Risk vs Negligible Risk: t=15.1082, p=0.0000 *
# Severe Risk vs Negligible Risk: t=14.3845, p=0.0000 *
# /var/folders/cm/69k42yy95z5gwss1vrkqcdgm0000gn/T/ipykernel_3987/1251730238.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['industry_mean_volatility'] = df.groupby('industry_group')['volatility'].transform('mean')
# /var/folders/cm/69k42yy95z5gwss1vrkqcdgm0000gn/T/ipykernel_3987/1251730238.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adjusted_volatility'] = df['volatility'] - df['industry_mean_volatility']
